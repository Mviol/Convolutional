# %%
import os
import math
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, VGG19
from tensorflow.keras import models, layers, optimizers
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

data_dir = r"C:\Users\mttvi\OneDrive\Área de Trabalho\DB2\Feijaoorg"

img_size = (256, 256)
batch_size = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

def plot_training(history, model_name):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b', label='Training accuracy')
    plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
    plt.title(f'{model_name} - Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(f'{model_name} - Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

def plot_confusion_matrix(model, generator):
    y_true = generator.classes
    num_batches = int(np.ceil(generator.samples / batch_size))
    y_pred = []

    for i in range(num_batches):
        batch_x, batch_y = generator.next()
        pred_batch = model.predict(batch_x)
        y_pred.extend(np.argmax(pred_batch, axis=-1))

    y_pred = np.array(y_pred)
    
    cm = confusion_matrix(y_true, y_pred, labels=list(train_generator.class_indices.values()))

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

names = ['CBC', 'CD', 'CI', 'CM', 'CNFCS', 'BG', 'MC', 'PE', 'TG']
nk = [9, 10, 9, 7, 8, 9, 8, 10, 10]

# VGG16
vgg16_model = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

for layer in vgg16_model.layers:
    layer.trainable = False

model_vgg16 = models.Sequential()
model_vgg16.add(vgg16_model)
model_vgg16.add(layers.Flatten())
model_vgg16.add(layers.Dense(256, activation='relu'))
model_vgg16.add(layers.Dropout(0.5))
model_vgg16.add(layers.Dense(len(names), activation='softmax'))

model_vgg16.compile(
    optimizer=optimizers.Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_vgg16 = model_vgg16.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=50,
    validation_data=val_generator,
    validation_steps=math.ceil(val_generator.samples / batch_size)
)

val_loss_vgg16, val_acc_vgg16 = model_vgg16.evaluate(val_generator, steps=math.ceil(val_generator.samples / batch_size))
print(f'VGG16 Validation Accuracy: {val_acc_vgg16 * 100:.2f}%')

plot_training(history_vgg16, 'VGG16')

plot_confusion_matrix(model_vgg16, val_generator)

predictions_vgg16 = model_vgg16.predict(val_generator)
y_true_vgg16 = val_generator.classes
y_pred_vgg16 = np.argmax(predictions_vgg16, axis=1)
class_labels_vgg16 = list(train_generator.class_indices.keys())

print("Classification Report - VGG16:\n", classification_report(y_true_vgg16, y_pred_vgg16, target_names=class_labels_vgg16))

vgg19_model = VGG19(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

for layer in vgg19_model.layers:
    layer.trainable = False

model_vgg19 = models.Sequential()
model_vgg19.add(vgg19_model)
model_vgg19.add(layers.Flatten())
model_vgg19.add(layers.Dense(256, activation='relu'))
model_vgg19.add(layers.Dropout(0.5))
model_vgg19.add(layers.Dense(len(names), activation='softmax'))

model_vgg19.compile(
    optimizer=optimizers.Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_vgg19 = model_vgg19.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=50,
    validation_data=val_generator,
    validation_steps=math.ceil(val_generator.samples / batch_size)
)

val_loss_vgg19, val_acc_vgg19 = model_vgg19.evaluate(val_generator, steps=math.ceil(val_generator.samples / batch_size))
print(f'VGG19 Validation Accuracy: {val_acc_vgg19 * 100:.2f}%')

# Plotar treinamento
plot_training(history_vgg19, 'VGG19')

# Plotar matriz de confusão
plot_confusion_matrix(model_vgg19, val_generator)

# Classification Report
predictions_vgg19 = model_vgg19.predict(val_generator)
y_true_vgg19 = val_generator.classes
y_pred_vgg19 = np.argmax(predictions_vgg19, axis=1)
class_labels_vgg19 = list(train_generator.class_indices.keys())

print("Classification Report - VGG19:\n", classification_report(y_true_vgg19, y_pred_vgg19, target_names=class_labels_vgg19))
# Out:
# Found 72 images belonging to 9 classes.
# Found 18 images belonging to 9 classes.
# Epoch 1/50
# 2/2 [==============================] - 104s 60s/step - loss: 5.7080 - accuracy: 0.1094 - val_loss: 7.2092 - val_accuracy: 0.1111
# Epoch 2/50
# 2/2 [==============================] - 62s 26s/step - loss: 8.7757 - accuracy: 0.2000 - val_loss: 6.0659 - val_accuracy: 0.2778
# Epoch 3/50
# 2/2 [==============================] - 78s 43s/step - loss: 6.9881 - accuracy: 0.1875 - val_loss: 4.2003 - val_accuracy: 0.3333
# Epoch 4/50
# 2/2 [==============================] - 73s 40s/step - loss: 4.6114 - accuracy: 0.2344 - val_loss: 2.7619 - val_accuracy: 0.3889
# Epoch 5/50
# 2/2 [==============================] - 58s 27s/step - loss: 3.2323 - accuracy: 0.2250 - val_loss: 2.2619 - val_accuracy: 0.2778
# Epoch 6/50
# 2/2 [==============================] - 73s 40s/step - loss: 2.7228 - accuracy: 0.1719 - val_loss: 2.0895 - val_accuracy: 0.2222
# Epoch 7/50
# 2/2 [==============================] - 75s 42s/step - loss: 2.3260 - accuracy: 0.2656 - val_loss: 2.0088 - val_accuracy: 0.1667
# Epoch 8/50
# 2/2 [==============================] - 60s 27s/step - loss: 1.9024 - accuracy: 0.3250 - val_loss: 1.9909 - val_accuracy: 0.3333
# Epoch 9/50
# 2/2 [==============================] - 64s 29s/step - loss: 1.7449 - accuracy: 0.4250 - val_loss: 2.0568 - val_accuracy: 0.2222
# Epoch 10/50
# 2/2 [==============================] - 60s 28s/step - loss: 1.9234 - accuracy: 0.3500 - val_loss: 2.0122 - val_accuracy: 0.2778
# Epoch 11/50
# 2/2 [==============================] - 74s 40s/step - loss: 1.8805 - accuracy: 0.2812 - val_loss: 1.9838 - val_accuracy: 0.1667
# Epoch 12/50
# 2/2 [==============================] - 59s 46s/step - loss: 2.0181 - accuracy: 0.2000 - val_loss: 1.9226 - val_accuracy: 0.2222
# Epoch 13/50
# 2/2 [==============================] - 57s 26s/step - loss: 1.8322 - accuracy: 0.3750 - val_loss: 1.9000 - val_accuracy: 0.3333
# Epoch 14/50
# 2/2 [==============================] - 59s 46s/step - loss: 1.9895 - accuracy: 0.2000 - val_loss: 1.9007 - val_accuracy: 0.2778
# Epoch 15/50
# 2/2 [==============================] - 60s 28s/step - loss: 1.5939 - accuracy: 0.3250 - val_loss: 1.9266 - val_accuracy: 0.2222
# Epoch 16/50
# 2/2 [==============================] - 60s 27s/step - loss: 1.6099 - accuracy: 0.4750 - val_loss: 1.9052 - val_accuracy: 0.2778
# Epoch 17/50
# 2/2 [==============================] - 75s 40s/step - loss: 1.7908 - accuracy: 0.2656 - val_loss: 1.8863 - val_accuracy: 0.3889
# Epoch 18/50
# 2/2 [==============================] - 60s 29s/step - loss: 1.6714 - accuracy: 0.4000 - val_loss: 1.8954 - val_accuracy: 0.3333
# Epoch 19/50
# 2/2 [==============================] - 60s 46s/step - loss: 1.6610 - accuracy: 0.3500 - val_loss: 1.8800 - val_accuracy: 0.3889
# Epoch 20/50
# 2/2 [==============================] - 57s 26s/step - loss: 1.5378 - accuracy: 0.3750 - val_loss: 1.8856 - val_accuracy: 0.2778
# Epoch 21/50
# 2/2 [==============================] - 73s 40s/step - loss: 1.6441 - accuracy: 0.2969 - val_loss: 1.8731 - val_accuracy: 0.3333
# Epoch 22/50
# 2/2 [==============================] - 60s 28s/step - loss: 1.4468 - accuracy: 0.4750 - val_loss: 1.8103 - val_accuracy: 0.4444
# Epoch 23/50
# 2/2 [==============================] - 59s 27s/step - loss: 1.5398 - accuracy: 0.4750 - val_loss: 1.7460 - val_accuracy: 0.5000
# Epoch 24/50
# 2/2 [==============================] - 59s 47s/step - loss: 1.7424 - accuracy: 0.3500 - val_loss: 1.7228 - val_accuracy: 0.5000
# Epoch 25/50
# 2/2 [==============================] - 62s 27s/step - loss: 1.6549 - accuracy: 0.3000 - val_loss: 1.6798 - val_accuracy: 0.5000
# Epoch 26/50
# 2/2 [==============================] - 72s 38s/step - loss: 1.3565 - accuracy: 0.5781 - val_loss: 1.6617 - val_accuracy: 0.5000
# Epoch 27/50
# 2/2 [==============================] - 73s 39s/step - loss: 1.6653 - accuracy: 0.3594 - val_loss: 1.6066 - val_accuracy: 0.5000
# Epoch 28/50
# 2/2 [==============================] - 74s 39s/step - loss: 1.4028 - accuracy: 0.4688 - val_loss: 1.6040 - val_accuracy: 0.5000
# Epoch 29/50
# 2/2 [==============================] - 57s 44s/step - loss: 1.4426 - accuracy: 0.5000 - val_loss: 1.5747 - val_accuracy: 0.5556
# Epoch 30/50
# 2/2 [==============================] - 57s 45s/step - loss: 1.4119 - accuracy: 0.4750 - val_loss: 1.5738 - val_accuracy: 0.3889
# Epoch 31/50
# 2/2 [==============================] - 73s 39s/step - loss: 1.4300 - accuracy: 0.4531 - val_loss: 1.5613 - val_accuracy: 0.3889
# Epoch 32/50
# 2/2 [==============================] - 57s 26s/step - loss: 1.3085 - accuracy: 0.5500 - val_loss: 1.5111 - val_accuracy: 0.4444
# Epoch 33/50
# 2/2 [==============================] - 73s 39s/step - loss: 1.3401 - accuracy: 0.5625 - val_loss: 1.4194 - val_accuracy: 0.5000
# Epoch 34/50
# 2/2 [==============================] - 57s 45s/step - loss: 1.2771 - accuracy: 0.4500 - val_loss: 1.3841 - val_accuracy: 0.5000
# Epoch 35/50
# 2/2 [==============================] - 58s 26s/step - loss: 1.2023 - accuracy: 0.5000 - val_loss: 1.3828 - val_accuracy: 0.6667
# Epoch 36/50
# 2/2 [==============================] - 58s 27s/step - loss: 1.2476 - accuracy: 0.5250 - val_loss: 1.4229 - val_accuracy: 0.5000
# Epoch 37/50
# 2/2 [==============================] - 58s 27s/step - loss: 1.2144 - accuracy: 0.5750 - val_loss: 1.4486 - val_accuracy: 0.5000
# Epoch 38/50
# 2/2 [==============================] - 59s 45s/step - loss: 1.1413 - accuracy: 0.5000 - val_loss: 1.3784 - val_accuracy: 0.5000
# Epoch 39/50
# 2/2 [==============================] - 60s 47s/step - loss: 1.0382 - accuracy: 0.6250 - val_loss: 1.3494 - val_accuracy: 0.5000
# Epoch 40/50
# 2/2 [==============================] - 58s 26s/step - loss: 0.9007 - accuracy: 0.6250 - val_loss: 1.3512 - val_accuracy: 0.5556
# Epoch 41/50
# 2/2 [==============================] - 73s 39s/step - loss: 1.3889 - accuracy: 0.5469 - val_loss: 1.3146 - val_accuracy: 0.5000
# Epoch 42/50
# 2/2 [==============================] - 57s 45s/step - loss: 1.2790 - accuracy: 0.5500 - val_loss: 1.3164 - val_accuracy: 0.6111
# Epoch 43/50
# 2/2 [==============================] - 57s 45s/step - loss: 1.1693 - accuracy: 0.5500 - val_loss: 1.3517 - val_accuracy: 0.6111
# Epoch 44/50
# 2/2 [==============================] - 57s 45s/step - loss: 1.0774 - accuracy: 0.6750 - val_loss: 1.3872 - val_accuracy: 0.5556
# Epoch 45/50
# 2/2 [==============================] - 58s 26s/step - loss: 1.0719 - accuracy: 0.5750 - val_loss: 1.3726 - val_accuracy: 0.6111
# Epoch 46/50
# 2/2 [==============================] - 58s 45s/step - loss: 1.2295 - accuracy: 0.6000 - val_loss: 1.3463 - val_accuracy: 0.5556
# Epoch 47/50
# 2/2 [==============================] - 74s 41s/step - loss: 1.2783 - accuracy: 0.4844 - val_loss: 1.2951 - val_accuracy: 0.5556
# Epoch 48/50
# 2/2 [==============================] - 59s 27s/step - loss: 1.1101 - accuracy: 0.5750 - val_loss: 1.2474 - val_accuracy: 0.6111
# Epoch 49/50
# 2/2 [==============================] - 56s 44s/step - loss: 0.9003 - accuracy: 0.7000 - val_loss: 1.2460 - val_accuracy: 0.6111
# Epoch 50/50
# 2/2 [==============================] - 56s 44s/step - loss: 1.3188 - accuracy: 0.4500 - val_loss: 1.2328 - val_accuracy: 0.7222
# 1/1 [==============================] - 20s 20s/step - loss: 1.2328 - accuracy: 0.7222
# VGG16 Validation Accuracy: 72.22%
# 1/1 [==============================] - 22s 22s/step
# 1/1 [==============================] - 22s 22s/step
# Classification Report - VGG16:
#                precision    recall  f1-score   support
#
#          CBC       0.33      0.50      0.40         2
#           CD       0.00      0.00      0.00         2
#           CI       0.00      0.00      0.00         2
#           CM       0.00      0.00      0.00         2
#        CNFCS       0.00      0.00      0.00         2
#           GB       0.00      0.00      0.00         2
#           MC       0.00      0.00      0.00         2
#           PE       0.50      0.50      0.50         2
#           TG       0.00      0.00      0.00         2
#
#     accuracy                           0.11        18
#    macro avg       0.09      0.11      0.10        18
# weighted avg       0.09      0.11      0.10        18
# C:\Users\mttvi\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mttvi\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mttvi\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/50
# 2/2 [==============================] - 99s 55s/step - loss: 8.5832 - accuracy: 0.0781 - val_loss: 9.0244 - val_accuracy: 0.1111
# Epoch 2/50
# 2/2 [==============================] - 88s 47s/step - loss: 10.5461 - accuracy: 0.1406 - val_loss: 6.8057 - val_accuracy: 0.1111
# Epoch 3/50
# 2/2 [==============================] - 70s 31s/step - loss: 8.8040 - accuracy: 0.2000 - val_loss: 5.1813 - val_accuracy: 0.1111
# Epoch 4/50
# 2/2 [==============================] - 65s 51s/step - loss: 7.1663 - accuracy: 0.1500 - val_loss: 4.9192 - val_accuracy: 0.1667
# Epoch 5/50
# 2/2 [==============================] - 65s 50s/step - loss: 5.5625 - accuracy: 0.2500 - val_loss: 3.9326 - val_accuracy: 0.1667
# Epoch 6/50
# 2/2 [==============================] - 83s 45s/step - loss: 5.3976 - accuracy: 0.1719 - val_loss: 3.2475 - val_accuracy: 0.2778
# Epoch 7/50
# 2/2 [==============================] - 64s 30s/step - loss: 3.5649 - accuracy: 0.3000 - val_loss: 2.5715 - val_accuracy: 0.2222
# Epoch 8/50
# 2/2 [==============================] - 80s 46s/step - loss: 2.6791 - accuracy: 0.1250 - val_loss: 2.0689 - val_accuracy: 0.2222
# Epoch 9/50
# 2/2 [==============================] - 66s 30s/step - loss: 2.2100 - accuracy: 0.2250 - val_loss: 2.2096 - val_accuracy: 0.2222
# Epoch 10/50
# 2/2 [==============================] - 66s 30s/step - loss: 2.1169 - accuracy: 0.2250 - val_loss: 2.1340 - val_accuracy: 0.2222
# Epoch 11/50
# 2/2 [==============================] - 43s 29s/step - loss: 2.0146 - accuracy: 0.1500 - val_loss: 2.0626 - val_accuracy: 0.2778
# Epoch 12/50
# 2/2 [==============================] - 34s 27s/step - loss: 1.9172 - accuracy: 0.3000 - val_loss: 2.0374 - val_accuracy: 0.2778
# Epoch 13/50
# 2/2 [==============================] - 34s 15s/step - loss: 1.9284 - accuracy: 0.2500 - val_loss: 1.9849 - val_accuracy: 0.2778
# Epoch 14/50
# 2/2 [==============================] - 34s 27s/step - loss: 1.9644 - accuracy: 0.2250 - val_loss: 1.9048 - val_accuracy: 0.2778
# Epoch 15/50
# 2/2 [==============================] - 35s 16s/step - loss: 1.9351 - accuracy: 0.3500 - val_loss: 1.8982 - val_accuracy: 0.0556
# Epoch 16/50
# 2/2 [==============================] - 35s 27s/step - loss: 1.9221 - accuracy: 0.1250 - val_loss: 1.9203 - val_accuracy: 0.0556
# Epoch 17/50
# 2/2 [==============================] - 34s 16s/step - loss: 1.8562 - accuracy: 0.2250 - val_loss: 1.9255 - val_accuracy: 0.2778
# Epoch 18/50
# 2/2 [==============================] - 34s 27s/step - loss: 1.6673 - accuracy: 0.3250 - val_loss: 1.8862 - val_accuracy: 0.2778
# Epoch 19/50
# 2/2 [==============================] - 35s 28s/step - loss: 1.7160 - accuracy: 0.3750 - val_loss: 1.8648 - val_accuracy: 0.2778
# Epoch 20/50
# 2/2 [==============================] - 36s 17s/step - loss: 1.7662 - accuracy: 0.2250 - val_loss: 1.8437 - val_accuracy: 0.3333
# Epoch 21/50
# 2/2 [==============================] - 38s 29s/step - loss: 1.6272 - accuracy: 0.3250 - val_loss: 1.8139 - val_accuracy: 0.3333
# Epoch 22/50
# 2/2 [==============================] - 37s 17s/step - loss: 1.6959 - accuracy: 0.3500 - val_loss: 1.7859 - val_accuracy: 0.3333
# Epoch 23/50
# 2/2 [==============================] - 44s 25s/step - loss: 1.7322 - accuracy: 0.3125 - val_loss: 1.8194 - val_accuracy: 0.2778
# Epoch 24/50
# 2/2 [==============================] - 45s 25s/step - loss: 1.7002 - accuracy: 0.3750 - val_loss: 1.8151 - val_accuracy: 0.3333
# Epoch 25/50
# 2/2 [==============================] - 45s 25s/step - loss: 1.7415 - accuracy: 0.2969 - val_loss: 1.7793 - val_accuracy: 0.3333
# Epoch 26/50
# 2/2 [==============================] - 45s 26s/step - loss: 1.7369 - accuracy: 0.2344 - val_loss: 1.7597 - val_accuracy: 0.3889
# Epoch 27/50
# 2/2 [==============================] - 45s 25s/step - loss: 1.7495 - accuracy: 0.2188 - val_loss: 1.7642 - val_accuracy: 0.4444
# Epoch 28/50
# 2/2 [==============================] - 35s 28s/step - loss: 1.6203 - accuracy: 0.2750 - val_loss: 1.7409 - val_accuracy: 0.4444
# Epoch 29/50
# 2/2 [==============================] - 34s 16s/step - loss: 1.6257 - accuracy: 0.4000 - val_loss: 1.7197 - val_accuracy: 0.3889
# Epoch 30/50
# 2/2 [==============================] - 46s 26s/step - loss: 1.6562 - accuracy: 0.3906 - val_loss: 1.7275 - val_accuracy: 0.3889
# Epoch 31/50
# 2/2 [==============================] - 35s 28s/step - loss: 1.5740 - accuracy: 0.3750 - val_loss: 1.7363 - val_accuracy: 0.3889
# Epoch 32/50
# 2/2 [==============================] - 35s 16s/step - loss: 1.5815 - accuracy: 0.3500 - val_loss: 1.7142 - val_accuracy: 0.3333
# Epoch 33/50
# 2/2 [==============================] - 35s 16s/step - loss: 1.4429 - accuracy: 0.4500 - val_loss: 1.7121 - val_accuracy: 0.3889
# Epoch 34/50
# 2/2 [==============================] - 35s 28s/step - loss: 1.4950 - accuracy: 0.4500 - val_loss: 1.7479 - val_accuracy: 0.3333
# Epoch 35/50
# 2/2 [==============================] - 35s 28s/step - loss: 1.4596 - accuracy: 0.4000 - val_loss: 1.7378 - val_accuracy: 0.3333
# Epoch 36/50
# 2/2 [==============================] - 38s 17s/step - loss: 1.6331 - accuracy: 0.3250 - val_loss: 1.8115 - val_accuracy: 0.4444
# Epoch 37/50
# 2/2 [==============================] - 46s 26s/step - loss: 1.4967 - accuracy: 0.4219 - val_loss: 1.8495 - val_accuracy: 0.4444
# Epoch 38/50
# 2/2 [==============================] - 34s 27s/step - loss: 1.8479 - accuracy: 0.2000 - val_loss: 1.7402 - val_accuracy: 0.5556
# Epoch 39/50
# 2/2 [==============================] - 35s 28s/step - loss: 1.5517 - accuracy: 0.5000 - val_loss: 1.7175 - val_accuracy: 0.5000
# Epoch 40/50
# 2/2 [==============================] - 35s 16s/step - loss: 1.4817 - accuracy: 0.4750 - val_loss: 1.7800 - val_accuracy: 0.3889
# Epoch 41/50
# 2/2 [==============================] - 49s 29s/step - loss: 1.5991 - accuracy: 0.3906 - val_loss: 1.7682 - val_accuracy: 0.2778
# Epoch 42/50
# 2/2 [==============================] - 39s 30s/step - loss: 1.5584 - accuracy: 0.3750 - val_loss: 1.6672 - val_accuracy: 0.3333
# Epoch 43/50
# 2/2 [==============================] - 47s 27s/step - loss: 1.4422 - accuracy: 0.4062 - val_loss: 1.6173 - val_accuracy: 0.3333
# Epoch 44/50
# 2/2 [==============================] - 47s 26s/step - loss: 1.5060 - accuracy: 0.4062 - val_loss: 1.6338 - val_accuracy: 0.3333
# Epoch 45/50
# 2/2 [==============================] - 81s 61s/step - loss: 1.3690 - accuracy: 0.4750 - val_loss: 1.6508 - val_accuracy: 0.4444
# Epoch 46/50
# 2/2 [==============================] - 37s 17s/step - loss: 1.5427 - accuracy: 0.4000 - val_loss: 1.6142 - val_accuracy: 0.4444
# Epoch 47/50
# 2/2 [==============================] - 36s 29s/step - loss: 1.3731 - accuracy: 0.4500 - val_loss: 1.6001 - val_accuracy: 0.4444
# Epoch 48/50
# 2/2 [==============================] - 47s 26s/step - loss: 1.4628 - accuracy: 0.4062 - val_loss: 1.6679 - val_accuracy: 0.3889
# Epoch 49/50
# 2/2 [==============================] - 43s 21s/step - loss: 1.4720 - accuracy: 0.3000 - val_loss: 1.7632 - val_accuracy: 0.4444
# Epoch 50/50
# 2/2 [==============================] - 41s 17s/step - loss: 1.5217 - accuracy: 0.3500 - val_loss: 1.6757 - val_accuracy: 0.3889
# 1/1 [==============================] - 12s 12s/step - loss: 1.6757 - accuracy: 0.3889
# VGG19 Validation Accuracy: 38.89%
# 1/1 [==============================] - 13s 13s/step
# 1/1 [==============================] - 14s 14s/step
# Classification Report - VGG19:
#                precision    recall  f1-score   support
#
#          CBC       0.00      0.00      0.00       2.0
#           CD       0.00      0.00      0.00       2.0
#           CI       0.00      0.00      0.00       2.0
#           CM       0.00      0.00      0.00       2.0
#        CNFCS       0.00      0.00      0.00       2.0
#           GB       0.00      0.00      0.00       2.0
#           MC       0.00      0.00      0.00       2.0
#           PE       0.00      0.00      0.00       2.0
#           TG       0.00      0.00      0.00       2.0
#
#     accuracy                           0.00      18.0
#    macro avg       0.00      0.00      0.00      18.0
# weighted avg       0.00      0.00      0.00      18.0
# C:\Users\mttvi\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mttvi\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mttvi\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
